# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# TODO: Make all necessary imports.

# General

import warnings
import logging
import time
import os
import numpy as np
import json

# Visualization
import matplotlib.pyplot as plt

# Neural Networks
import tensorflow as tf

# Data
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# Data Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Model
import tensorflow_hub as hub
from tensorflow import keras

# %%
# Logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# Visualizations
# %matplotlib inline

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# TODO: Load the dataset with TensorFlow Datasets.

# TODO: Create a training set, a validation set and a test set.

(train, validation, test), dataset_info = tfds.load("oxford_flowers102",split=[
    tfds.core.ReadInstruction('train', to=100, unit='%'),
    tfds.core.ReadInstruction('validation', to=100, unit='%'),
    tfds.core.ReadInstruction('test', to=100, unit='%')],
     as_supervised=True,
     with_info=True)

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.

# TODO: Get the number of classes in the dataset from the dataset info.

n_training_records = dataset_info.splits['train'].num_examples
n_validation_records = dataset_info.splits['validation'].num_examples
n_test_records = dataset_info.splits['test'].num_examples

n_total_records = n_training_records + n_validation_records + n_test_records

num_classes = dataset_info.features['label'].num_classes

print('\nNumber of training records:',n_training_records)
print('\nNumber of validation records:',n_validation_records)
print('\nNumber of test records:',n_test_records)
print('\nTotal number of records:',n_total_records)
print('\nNumber of classes:',num_classes)
# Out:
# Number of training records: 1020
#
# Number of validation records: 1020
#
# Number of test records: 6149
#
# Total number of records: 8189
#
# Number of classes: 102

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
def image_details(dataset, n_images):

  images = []
  labels =[]

  for i in range(n_images):
    for image, label in dataset.take(i):
      image = image.numpy().squeeze()
      label = label.numpy()
      images.append(image)
      labels.append(label)
      
  for i in range(len(images)):
    print('\nShape of image',i,'is:', images[i].shape)
    print('Label of image',i,'is:',labels[i])

# %%
image_details(train,3)
# Out:
# Shape of image 0 is: (500, 667, 3)
# Label of image 0 is: 72
#
# Shape of image 1 is: (500, 667, 3)
# Label of image 1 is: 72
#
# Shape of image 2 is: (500, 666, 3)
# Label of image 2 is: 84

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 

for image, label in train.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()

plt.imshow(image, cmap= plt.cm.binary)
plt.title(label)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a32e6e11-9d39-4d47-9ea4-5b59c3509361" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a32e6e11-9d39-4d47-9ea4-5b59c3509361">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving label_map.json to label_map (1).json

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 

for image, label in train.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()
    for key, val in class_names.items():
      if key == str(label):
        value = val

plt.imshow(image, cmap= plt.cm.binary)
plt.title(value)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.

def format_image(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (image_size, image_size))
    image /= 255
    return image, label

batch_size = 32
image_size = 224

training_batches = train.shuffle(n_training_records//4).map(format_image).batch(batch_size).prefetch(1)
validation_batches = validation.map(format_image).batch(batch_size).prefetch(1)
testing_batches = test.map(format_image).batch(batch_size).prefetch(1)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %% [markdown]
# ## 1. Base Model

# %%
# TODO: Build and train your network.

URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL, input_shape=(image_size, image_size, 3))

# %%
model = tf.keras.Sequential()

model.add(feature_extractor)

model.add(tf.keras.layers.Flatten(input_shape = (image_size, image_size, 3)))

model.add(tf.keras.layers.Dense(64, activation='relu'))

model.add(tf.keras.layers.Dense(102, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                81984
# _________________________________________________________________
# dense_5 (Dense)              (None, 102)               6630
# =================================================================
# Total params: 2,346,598
# Trainable params: 88,614
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
EPOCHS = 100
history = model.fit(training_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 6s 176ms/step - loss: 4.5371 - accuracy: 0.0422 - val_loss: 4.2217 - val_accuracy: 0.1039
# Epoch 2/100
# 32/32 [==============================] - 5s 163ms/step - loss: 3.7286 - accuracy: 0.2245 - val_loss: 3.4425 - val_accuracy: 0.2627
# Epoch 3/100
# 32/32 [==============================] - 5s 164ms/step - loss: 2.6420 - accuracy: 0.5078 - val_loss: 2.5904 - val_accuracy: 0.4686
# Epoch 4/100
# 32/32 [==============================] - 5s 162ms/step - loss: 1.7925 - accuracy: 0.6951 - val_loss: 2.0073 - val_accuracy: 0.5882
# Epoch 5/100
# 32/32 [==============================] - 5s 161ms/step - loss: 1.2219 - accuracy: 0.8127 - val_loss: 1.6687 - val_accuracy: 0.6529
# Epoch 6/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.8676 - accuracy: 0.8745 - val_loss: 1.4536 - val_accuracy: 0.6843
# Epoch 7/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.6483 - accuracy: 0.9147 - val_loss: 1.3328 - val_accuracy: 0.7108
# Epoch 8/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.4906 - accuracy: 0.9422 - val_loss: 1.2070 - val_accuracy: 0.7333
# Epoch 9/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.3715 - accuracy: 0.9696 - val_loss: 1.1394 - val_accuracy: 0.7343
# Epoch 10/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.2930 - accuracy: 0.9853 - val_loss: 1.0882 - val_accuracy: 0.7461
# Epoch 11/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.2334 - accuracy: 0.9912 - val_loss: 1.0432 - val_accuracy: 0.7627
# Epoch 12/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.1931 - accuracy: 0.9951 - val_loss: 1.0125 - val_accuracy: 0.7451
# Epoch 13/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.1517 - accuracy: 0.9980 - val_loss: 0.9788 - val_accuracy: 0.7627
# Epoch 14/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.1261 - accuracy: 0.9971 - val_loss: 0.9634 - val_accuracy: 0.7549
# Epoch 15/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.1045 - accuracy: 0.9990 - val_loss: 0.9302 - val_accuracy: 0.7667
# Epoch 16/100
# 32/32 [==============================] - 5s 161ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.9260 - val_accuracy: 0.7696
# Epoch 17/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0769 - accuracy: 1.0000 - val_loss: 0.9112 - val_accuracy: 0.7618
# Epoch 18/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.7637
# Epoch 19/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.8944 - val_accuracy: 0.7676
# Epoch 20/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.8870 - val_accuracy: 0.7716
# Epoch 21/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 0.8804 - val_accuracy: 0.7706
# Epoch 22/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.8731 - val_accuracy: 0.7735
# Epoch 23/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.8673 - val_accuracy: 0.7725
# Epoch 24/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.8656 - val_accuracy: 0.7735
# Epoch 25/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.7794
# Epoch 26/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.8605 - val_accuracy: 0.7716
# Epoch 27/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.8556 - val_accuracy: 0.7765
# Epoch 28/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.8543 - val_accuracy: 0.7784
# Epoch 29/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.8491 - val_accuracy: 0.7833
# Epoch 30/100
# 32/32 [==============================] - 5s 169ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.8433 - val_accuracy: 0.7863
# Epoch 31/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.8423 - val_accuracy: 0.7824
# Epoch 32/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.8445 - val_accuracy: 0.7853
# Epoch 33/100
# 32/32 [==============================] - 5s 161ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.8409 - val_accuracy: 0.7863
# Epoch 34/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.8400 - val_accuracy: 0.7863
# Epoch 35/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.8367 - val_accuracy: 0.7833
# Epoch 36/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.8356 - val_accuracy: 0.7843
# Epoch 37/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.8362 - val_accuracy: 0.7873
# Epoch 38/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.8348 - val_accuracy: 0.7843
# Epoch 39/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.8310 - val_accuracy: 0.7863
# Epoch 40/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.8350 - val_accuracy: 0.7873
# Epoch 41/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.8324 - val_accuracy: 0.7912
# Epoch 42/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.8314 - val_accuracy: 0.7892
# Epoch 43/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.8327 - val_accuracy: 0.7843
# Epoch 44/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.8306 - val_accuracy: 0.7873
# Epoch 45/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.8308 - val_accuracy: 0.7873
# Epoch 46/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.8301 - val_accuracy: 0.7902
# Epoch 47/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.8283 - val_accuracy: 0.7922
# Epoch 48/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.8290 - val_accuracy: 0.7902
# Epoch 49/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.7873
# Epoch 50/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.8304 - val_accuracy: 0.7882
# Epoch 51/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.8278 - val_accuracy: 0.7922
# Epoch 52/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.8281 - val_accuracy: 0.7941
# Epoch 53/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8286 - val_accuracy: 0.7882
# Epoch 54/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.8301 - val_accuracy: 0.7863
# Epoch 55/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.8302 - val_accuracy: 0.7892
# Epoch 56/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.8273 - val_accuracy: 0.7922
# Epoch 57/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.8296 - val_accuracy: 0.7873
# Epoch 58/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.8303 - val_accuracy: 0.7873
# Epoch 59/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.8281 - val_accuracy: 0.7892
# Epoch 60/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8293 - val_accuracy: 0.7873
# Epoch 61/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.8295 - val_accuracy: 0.7882
# Epoch 62/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.8293 - val_accuracy: 0.7873
# Epoch 63/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.8298 - val_accuracy: 0.7882
# Epoch 64/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.8304 - val_accuracy: 0.7882
# Epoch 65/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.8302 - val_accuracy: 0.7912
# Epoch 66/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8313 - val_accuracy: 0.7902
# Epoch 67/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.8321 - val_accuracy: 0.7882
# Epoch 68/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8301 - val_accuracy: 0.7912
# Epoch 69/100
# 32/32 [==============================] - 5s 161ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.8324 - val_accuracy: 0.7873
# Epoch 70/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8319 - val_accuracy: 0.7902
# Epoch 71/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.8314 - val_accuracy: 0.7912
# Epoch 72/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8317 - val_accuracy: 0.7931
# Epoch 73/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.8330 - val_accuracy: 0.7902
# Epoch 74/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.8332 - val_accuracy: 0.7892
# Epoch 75/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8336 - val_accuracy: 0.7882
# Epoch 76/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.8337 - val_accuracy: 0.7902
# Epoch 77/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.8342 - val_accuracy: 0.7902
# Epoch 78/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.8359 - val_accuracy: 0.7892
# Epoch 79/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.8348 - val_accuracy: 0.7912
# Epoch 80/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8366 - val_accuracy: 0.7902
# Epoch 81/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8374 - val_accuracy: 0.7902
# Epoch 82/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8361 - val_accuracy: 0.7931
# Epoch 83/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8364 - val_accuracy: 0.7882
# Epoch 84/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8366 - val_accuracy: 0.7902
# Epoch 85/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8383 - val_accuracy: 0.7931
# Epoch 86/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8382 - val_accuracy: 0.7912
# Epoch 87/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8376 - val_accuracy: 0.7882
# Epoch 88/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8394 - val_accuracy: 0.7902
# Epoch 89/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8395 - val_accuracy: 0.7912
# Epoch 90/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8391 - val_accuracy: 0.7912
# Epoch 91/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8411 - val_accuracy: 0.7922
# Epoch 92/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8414 - val_accuracy: 0.7892
# Epoch 93/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8423 - val_accuracy: 0.7902
# Epoch 94/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8408 - val_accuracy: 0.7912
# Epoch 95/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8429 - val_accuracy: 0.7882
# Epoch 96/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8425 - val_accuracy: 0.7922
# Epoch 97/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8434 - val_accuracy: 0.7931
# Epoch 98/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8437 - val_accuracy: 0.7892
# Epoch 99/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8456 - val_accuracy: 0.7902
# Epoch 100/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8458 - val_accuracy: 0.7912

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

print('The keys of history are:',list(history.history.keys()))
# Out:
# The keys of history are: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %%
# Accuracy
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Loss
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## 2. Improve Model

# %%
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL, input_shape=(image_size, image_size, 3))

# %%
model = tf.keras.Sequential()

model.add(feature_extractor)

model.add(tf.keras.layers.Flatten(input_shape = (image_size, image_size, 3)))

model.add(tf.keras.layers.Dense(64, activation='relu'))

model.add(tf.keras.layers.Dense(102, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_3 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                81984
# _________________________________________________________________
# dense_9 (Dense)              (None, 102)               6630
# =================================================================
# Total params: 2,346,598
# Trainable params: 88,614
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

EPOCHS = 100

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
history = model.fit(training_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 32/32 [==============================] - 6s 174ms/step - loss: 4.5489 - accuracy: 0.0324 - val_loss: 4.1918 - val_accuracy: 0.1157
# Epoch 2/100
# 32/32 [==============================] - 5s 164ms/step - loss: 3.6751 - accuracy: 0.2059 - val_loss: 3.3155 - val_accuracy: 0.2980
# Epoch 3/100
# 32/32 [==============================] - 5s 165ms/step - loss: 2.5383 - accuracy: 0.5245 - val_loss: 2.3635 - val_accuracy: 0.5343
# Epoch 4/100
# 32/32 [==============================] - 5s 164ms/step - loss: 1.5857 - accuracy: 0.7333 - val_loss: 1.8534 - val_accuracy: 0.6206
# Epoch 5/100
# 32/32 [==============================] - 5s 166ms/step - loss: 1.0604 - accuracy: 0.8363 - val_loss: 1.5698 - val_accuracy: 0.6510
# Epoch 6/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.7453 - accuracy: 0.9029 - val_loss: 1.3622 - val_accuracy: 0.6922
# Epoch 7/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.5302 - accuracy: 0.9441 - val_loss: 1.2470 - val_accuracy: 0.7108
# Epoch 8/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.3952 - accuracy: 0.9637 - val_loss: 1.1599 - val_accuracy: 0.7176
# Epoch 9/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.2948 - accuracy: 0.9765 - val_loss: 1.0650 - val_accuracy: 0.7529
# Epoch 10/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.2304 - accuracy: 0.9922 - val_loss: 1.0369 - val_accuracy: 0.7461
# Epoch 11/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.1772 - accuracy: 0.9971 - val_loss: 0.9899 - val_accuracy: 0.7529
# Epoch 12/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.1381 - accuracy: 0.9971 - val_loss: 0.9623 - val_accuracy: 0.7647
# Epoch 13/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.1084 - accuracy: 1.0000 - val_loss: 0.9472 - val_accuracy: 0.7569
# Epoch 14/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 0.9334 - val_accuracy: 0.7539
# Epoch 15/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.9062 - val_accuracy: 0.7676
# Epoch 16/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0648 - accuracy: 1.0000 - val_loss: 0.9008 - val_accuracy: 0.7657
# Epoch 17/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.8884 - val_accuracy: 0.7706
# Epoch 18/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.8823 - val_accuracy: 0.7696
# Epoch 19/100
# 32/32 [==============================] - 5s 170ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.8789 - val_accuracy: 0.7735
# Epoch 20/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.8649 - val_accuracy: 0.7686
# Epoch 21/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.8671 - val_accuracy: 0.7725
# Epoch 22/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.8599 - val_accuracy: 0.7716
# Epoch 23/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.8533 - val_accuracy: 0.7706
# Epoch 24/100
# 32/32 [==============================] - 5s 170ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.8531 - val_accuracy: 0.7814
# Epoch 25/100
# 32/32 [==============================] - 5s 171ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.8458 - val_accuracy: 0.7765
# Epoch 26/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.8412 - val_accuracy: 0.7735
# Epoch 27/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.8460 - val_accuracy: 0.7745
# Epoch 28/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.8385 - val_accuracy: 0.7765
# Epoch 29/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.8378 - val_accuracy: 0.7794
# Epoch 30/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.8372 - val_accuracy: 0.7794
# Epoch 31/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.8353 - val_accuracy: 0.7784
# Epoch 32/100
# 32/32 [==============================] - 5s 165ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.8300 - val_accuracy: 0.7775
# Epoch 33/100
# 32/32 [==============================] - 5s 169ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.8335 - val_accuracy: 0.7824
# Epoch 34/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.8308 - val_accuracy: 0.7814
# Epoch 35/100
# 32/32 [==============================] - 5s 169ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.7824
# Epoch 36/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.7804
# Epoch 37/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.8279 - val_accuracy: 0.7814
# Epoch 38/100
# 32/32 [==============================] - 5s 169ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.8267 - val_accuracy: 0.7804
# Epoch 39/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.8250 - val_accuracy: 0.7833
# Epoch 40/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.8254 - val_accuracy: 0.7814
# Epoch 41/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.8246 - val_accuracy: 0.7804
# Epoch 42/100
# 32/32 [==============================] - 5s 169ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.8248 - val_accuracy: 0.7824
# Epoch 43/100
# 32/32 [==============================] - 5s 169ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.8216 - val_accuracy: 0.7814
# Epoch 44/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.8223 - val_accuracy: 0.7784
# Epoch 45/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.8221 - val_accuracy: 0.7843
# Epoch 46/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.8230 - val_accuracy: 0.7794
# Epoch 47/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.8224 - val_accuracy: 0.7794
# Epoch 48/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8225 - val_accuracy: 0.7804

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.

loss, accuracy = model.evaluate(testing_batches)

print('Loss on test data: {:,.3f}'.format(loss))
print('Accuracy on test data: {:,.3f}'.format(accuracy))
# Out:
# 193/193 [==============================] - 17s 88ms/step - loss: 1.0089 - accuracy: 0.7479
# Loss on test data: 1.009
# Accuracy on test data: 0.748

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/Machine Learning/Udacity/Deep Learning/Project/Project Rubric
# Out:
# /content/gdrive/My Drive/Machine Learning/Udacity/Deep Learning/Project/Project Rubric

# %%
# !mkdir models

# %%
model.save('./models/saved_model.h5')

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model

path = './models/saved_model.h5'
loaded_model = tf.keras.models.load_model((path),custom_objects={'KerasLayer':hub.KerasLayer})

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function

def process_image(image):
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image = tf.image.resize(image, (image_size, image_size))
    image = image / 255
    return image.numpy()

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

def predict(image_path, model, top_k):
  img = Image.open(image_path)
  img = np.asarray(img)
  img = process_image(img)
  img = np.expand_dims(img, axis=0)
  probs = model.predict(img)

  values, idx = tf.nn.top_k(probs, k=top_k)
  values = values.numpy()
  idx = idx.numpy()

  return values, idx, img

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes

def show_images(image_path):
  img = Image.open(image_path)
  img = np.asarray(img)
  img = process_image(img)
  return img

# %%
images = ['cautleya_spicata.jpg', 'hard-leaved_pocket_orchid.jpg', 'orange_dahlia.jpg', 'wild_pansy.jpg']

for img in images:
    url = './test_images/{}'.format(img)
    top_k_values, top_k_indices, image = predict(url, loaded_model, 5)
    print('Propabilties:', top_k_values)
    print('Classes:', top_k_indices)
    
    flower_classes = []
    print("Classes:")
    for idx in top_k_indices[0]:
        print("-",class_names[str(idx+1)])
        flower_classes.append(class_names[str(idx+1)])
        
    fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
    image = show_images(url)
    ax1.imshow(image)
    ax1.set_title(flower_classes[0])
    ax2.barh(top_k_indices[0], top_k_values[0])
    ax2.set_yticks(top_k_indices[0])
    ax2.set_yticklabels(flower_classes);
    ax2.set_title('Probabilities')
    plt.tight_layout()
    plt.show()
# Out:
# Propabilties: [[9.9113727e-01 2.8108768e-03 1.8850955e-03 1.2994908e-03 6.9978740e-04]]
# Classes: [[60 37 23 45 14]]
# Classes:
# - cautleya spicata
# - great masterwort
# - red ginger
# - wallflower
# - yellow iris
# Propabilties: [[9.9968076e-01 8.3224135e-05 6.8449233e-05 6.2289451e-05 4.6724861e-05]]
# Classes: [[  1  66   2 101  67]]
# Classes:
# - hard-leaved pocket orchid
# - spring crocus
# - canterbury bells
# - blackberry lily
# - bearded iris
# Propabilties: [[0.41674286 0.29117322 0.10798176 0.07485186 0.02893454]]
# Classes: [[58  4 99 65 70]]
# Classes:
# - orange dahlia
# - english marigold
# - blanket flower
# - osteospermum
# - gazania
# Propabilties: [[9.9974042e-01 9.3721326e-05 5.3828506e-05 3.4429453e-05 2.4522949e-05]]
# Classes: [[51 63 33 18 64]]
# Classes:
# - wild pansy
# - silverbush
# - mexican aster
# - balloon flower
# - californian poppy
